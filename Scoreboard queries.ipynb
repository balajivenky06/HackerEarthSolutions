# %% [markdown]
# # Scoreboard queries

# %%
from IPython.display import Image
from IPython.display import display

# %%
a = Image(r'C:\Users\hp\Desktop\PersonalFolder\HackerEarth Code Challange\Scoreboard queries.png')
b = Image(r'C:\Users\hp\Desktop\PersonalFolder\HackerEarth Code Challange\Scoreboard queries1.png')
display(a,b)

# %%
t= int(input())
for _ in range(t):
    n, q = map(int, input().split())
    print("Given n:", n)
    print("Given q:", q)
    arr = list(map(int, input().split()))
    print("Given array:", arr)
    hav = dict()
    for val in arr:
        hav[val] = hav.get(val, 0) + 1
    print("hav:", hav)
    if q>0:
        for _ in range(q):
            l, r = map(int, input().split())
            print("Given l:", l)
            print("Given r:", r)
            l -= 1
            print("new l:", l)
            print("arr[l]:", arr[l])
            hav[arr[l]] -= 1
            print("new hav:", hav)
            if hav[arr[l]] == 0:
                hav.pop(arr[l])
            arr[l] = r
            print("new arr:", arr)
            hav[arr[l]] = hav.get(arr[l], 0) + 1
            print("final hav:", hav)
    print(len(hav)+1)
# Out:
# 1
# 4 1
# Given n: 4
# Given q: 1
# 2 1 1 5
# Given array: [2, 1, 1, 5]
# hav: {2: 1, 1: 2, 5: 1}
# 2 3
# Given l: 2
# Given r: 3
# new l: 1
# arr[l]: 1
# new hav: {2: 1, 1: 1, 5: 1}
# new arr: [2, 3, 1, 5]
# final hav: {2: 1, 1: 1, 5: 1, 3: 1}
# 5
