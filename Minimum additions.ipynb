# %% [markdown]
# # Minimum additions

# %%
from IPython.display import Image
from IPython.display import display

# %%
a = Image(r'C:\Users\hp\Desktop\PersonalFolder\HackerEarth Code Challange\Minimum additions.png')
b = Image(r'C:\Users\hp\Desktop\PersonalFolder\HackerEarth Code Challange\Minimum additions1.png')
display(a,b)

# %%
t = int(input())
for _ in range(t):
    n, k = map(int, input().split())
    print("n:", n , "k:", k)
    a = sum(map(int, input().split()))
    print("sum of array a:", a)
    print(max(0, a // (k + 1) - n + 1))
# Out:
# 1
# 2 1
# n: 2 k: 1
# 3 1
# sum of array a: 4
# 1
